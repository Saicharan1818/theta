# %% [markdown]
# <a href="https://colab.research.google.com/github/Saicharan1818/theta/blob/main/Cars24_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file_name ='/content/Car_Data.csv'
cars24 = pd.read_csv(file_name)
cars24
# Out:
#                      Name  Company       City  Year  KM_Driven  No._of_Owners  \
# 0              SKODARAPID    SKODA    Kolkata  2011      91907              2
# 1              HYUNDAII10  HYUNDAI  Bangalore  2022      29132              2
# 2            HYUNDAIXCENT  HYUNDAI     Indore  2022      64670              1
# 3          MARUTIALTO K10   MARUTI      Kochi  2016      65754              1
# 4       HYUNDAINEW SANTRO  HYUNDAI  Ahmedabad  2023      12548              1
# ...                   ...      ...        ...   ...        ...            ...
# 100236     MARUTIALTO 800   MARUTI  Bangalore  2014      33905              1
# 100237         MARUTIEECO   MARUTI  Ahmedabad  2022       8147              1
# 100238        TATAHARRIER     TATA    Chennai  2021       3507              1
# 100239  MARUTIWAGON R 1.0   MARUTI  Ghaziabad  2024      62153              1
# 100240         MARUTIEECO   MARUTI    Chennai  2011      62301              1
#
# ...

# %%
cars24.isnull()
# Out:
#          Name  Company   City   Year  KM_Driven  No._of_Owners  Fuel_Type  \
# 0       False    False  False  False      False          False      False
# 1       False    False  False  False      False          False      False
# 2       False    False  False  False      False          False      False
# 3       False    False  False  False      False          False      False
# 4       False    False  False  False      False          False      False
# ...       ...      ...    ...    ...        ...            ...        ...
# 100236  False    False  False  False      False          False      False
# 100237  False    False  False  False      False          False      False
# 100238  False    False  False  False      False          False      False
# 100239  False    False  False  False      False          False      False
# 100240  False    False  False  False      False          False      False
#
#         Calculated_Score  On_Road_Price
# ...

# %%
car24_data = cars24.dropna()
car24_data
# Out:
#                      Name  Company       City  Year  KM_Driven  No._of_Owners  \
# 0              SKODARAPID    SKODA    Kolkata  2011      91907              2
# 1              HYUNDAII10  HYUNDAI  Bangalore  2022      29132              2
# 2            HYUNDAIXCENT  HYUNDAI     Indore  2022      64670              1
# 3          MARUTIALTO K10   MARUTI      Kochi  2016      65754              1
# 4       HYUNDAINEW SANTRO  HYUNDAI  Ahmedabad  2023      12548              1
# ...                   ...      ...        ...   ...        ...            ...
# 100236     MARUTIALTO 800   MARUTI  Bangalore  2014      33905              1
# 100237         MARUTIEECO   MARUTI  Ahmedabad  2022       8147              1
# 100238        TATAHARRIER     TATA    Chennai  2021       3507              1
# 100239  MARUTIWAGON R 1.0   MARUTI  Ghaziabad  2024      62153              1
# 100240         MARUTIEECO   MARUTI    Chennai  2011      62301              1
#
# ...

# %%
car24_data =
